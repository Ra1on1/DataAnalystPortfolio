# %%
#Importieren von Bibliotheken
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

#Daten laden
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Datenbereinigung
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_GER = df[df['job_country'] == 'Germany']

# %%
df_skills = df_GER.explode('job_skills')

df_skills[['job_title','job_skills']]
# Out:
#                                                 job_title job_skills
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...     python
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...        sql
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...         c#
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...      azure
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...    airflow
# ...                                                   ...        ...
# 785735                               Senior Data Engineer     docker
# 785737                                   CRM Data Analyst        sas
# 785737                                   CRM Data Analyst        sas
# 785737                                   CRM Data Analyst        sql
# 785737                                   CRM Data Analyst      excel
#
# [112958 rows x 2 columns]

# %%
df_skills_count = df_skills.groupby(['job_skills', 'job_title_short']).size()

df_skills_count = df_skills_count.reset_index(name='skill_count')

df_skills_count.sort_values(by='skill_count', ascending=False, inplace=True)

df_skills_count
# Out:
#      job_skills job_title_short  skill_count
# 907      python  Data Scientist         4157
# 906      python   Data Engineer         3524
# 1139        sql   Data Engineer         3145
# 1138        sql    Data Analyst         2947
# 905      python    Data Analyst         2309
# ...         ...             ...          ...
# 1369       yarn    Data Analyst            1
# 1371       yarn  Data Scientist            1
# 1375       zoom   Data Engineer            1
# 792     outlook  Cloud Engineer            1
# 12      alteryx  Cloud Engineer            1
#
# [1382 rows x 3 columns]

# %%
job_titles = df_skills['job_title_short'].unique().tolist()

# Auswahl der Elemente von Position 3 bis 1, außer Position 0
job_titles = sorted(job_titles[3:0:-1])

job_titles
# Out:
# ['Data Analyst', 'Senior Data Analyst', 'Senior Data Scientist']

# %%
fig, ax = plt.subplots(len(job_titles),1)

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_count[df_skills_count['job_title_short'] == job_title].head(5)
    df_plot.plot(kind='barh', x='job_skills', y='skill_count', ax=ax[i], title=job_title)
    ax[i].invert_yaxis()
    ax[i].set_ylabel('')
    ax[i].legend().set_visible(False)

fig.suptitle('Anzahl der wichtigsten Fähigkeiten in Stellenausschreibungen', fontsize=15)
fig.tight_layout(h_pad=0.5)
plt.show()

# %%
df_jobs_title_count = df_GER['job_title_short'].value_counts().reset_index(name='jobs_total')

# %%
df_skills_perc = pd.merge(df_skills_count, df_jobs_title_count, how='left', on='job_title_short')

df_skills_perc['skill_percent'] = 100 * df_skills_perc['skill_count'] / df_skills_perc['jobs_total']

df_skills_perc
# Out:
#      job_skills job_title_short  skill_count  jobs_total  skill_percent
# 0        python  Data Scientist         4157        6745      61.630838
# 1        python   Data Engineer         3524        6675      52.794007
# 2           sql   Data Engineer         3145        6675      47.116105
# 3           sql    Data Analyst         2947        7131      41.326602
# 4        python    Data Analyst         2309        7131      32.379750
# ...         ...             ...          ...         ...            ...
# 1377       yarn    Data Analyst            1        7131       0.014023
# 1378       yarn  Data Scientist            1        6745       0.014826
# 1379       zoom   Data Engineer            1        6675       0.014981
# 1380    outlook  Cloud Engineer            1         189       0.529101
# 1381    alteryx  Cloud Engineer            1         189       0.529101
#
# [1382 rows x 5 columns]

# %%
fig, ax = plt.subplots(len(job_titles),1)

sns.set_theme(style='ticks')

for i, job_title in enumerate(job_titles):
    df_plot = df_skills_perc[df_skills_perc['job_title_short'] == job_title].head(5)
    sns.barplot(data=df_plot, x='skill_percent', y='job_skills', ax=ax[i], hue='skill_count', palette='dark:b_r')
    ax[i].set_title(job_title)
    ax[i].set_ylabel('')
    ax[i].set_xlabel('')
    ax[i].get_legend().remove()
    ax[i].set_xlim(0, 78)

    for n, v in enumerate(df_plot['skill_percent']):
        ax[i].text(v + 1, n, f'{v:.0f}%', va='center')

    if i != len(job_titles) - 1:
        ax[i].set_xticks([])

fig.suptitle('Wahrscheinlichkeit der in deutschen Stellen geforderten Fähigkeiten', fontsize=15)
fig.tight_layout(h_pad=0.5)
plt.show()
